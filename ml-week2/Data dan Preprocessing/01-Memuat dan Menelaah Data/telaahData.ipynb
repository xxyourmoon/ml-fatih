# %% [markdown]
# <div class="alert alert-block alert-info">
# <h2>Daftar Isi: </h2>
#     <ol>
#     <li>Memuat Data</li>
#     <li>Menelaah Data</li>
#     </ol>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Catatan : </b>Jika belum pernah instal library, gunakan perintah berikut secara inline atau melalui terminal.
#     <ol>
#     <li>!pip install pandas</li>
#     <li>!pip install numpy</li>
#     </ol>
# </div>

# %% [markdown]
# ## Memuat Data
# ---

# %%
# !pip install pandas

# %%
# import library
import pandas as pd
import numpy as np

# %%
# load dataset
path = "epl-goalScorer(20-21).csv"
df = pd.read_csv(path)

# %%
# menampilkan 5 baris awal dari dataset
df.head()
# Out:
#    Unnamed: 0    id      player_name  games  time  goals         xG  assists  \
# 0           0   647       Harry Kane     35  3097     23  22.174859       14
# 1           1  1250    Mohamed Salah     37  3085     22  20.250847        5
# 2           2  1228  Bruno Fernandes     37  3117     18  16.019454       12
# 3           3   453    Son Heung-Min     37  3139     17  11.023287       10
# 4           4   822  Patrick Bamford     38  3085     17  18.401863        7
#
#           xA  shots  key_passes  yellow_cards  red_cards position  \
# 0   7.577094    138          49             1          0        F
# 1   6.528526    126          55             0          0    F M S
# 2  11.474996    121          95             6          0      M S
# 3   9.512992     68          75             0          0    F M S
# 4   3.782247    107          30             3          0      F S
#
#           team_title  npg       npxG    xGChain  xGBuildup
# 0          Tottenham   19  19.130183  24.995648   4.451257
# 1          Liverpool   16  15.683834  28.968234   9.800236
# 2  Manchester United    9   8.407840  26.911412  11.932285
# 3          Tottenham   16  10.262118  20.671916   6.608751
# 4              Leeds   15  16.879525  23.394953   4.131796

# %%
# menampilkan 5 baris akhir dari dataset
df.tail()
# Out:
#      Unnamed: 0    id             player_name  games  time  goals        xG  \
# 517         517  9415  Jaden Philogene-Bidace      1     1      0  0.000000
# 518         518  9423         Gaetano Berardi      2   113      0  0.074761
# 519         519  9524          Anthony Elanga      1    67      0  0.000000
# 520         520  9540             Femi Seriki      1     1      0  0.000000
# 521         521  9552         Tyrese Francois      1    13      0  0.000000
#
#      assists   xA  shots  key_passes  yellow_cards  red_cards position  \
# 517        0  0.0      0           0             0          0        S
# 518        0  0.0      1           0             0          0      D S
# 519        0  0.0      0           0             0          0        M
# 520        0  0.0      0           0             0          0        S
# 521        0  0.0      0           0             0          0        S
#
#             team_title  npg      npxG   xGChain  xGBuildup
# 517        Aston Villa    0  0.000000  0.056044   0.056044
# 518              Leeds    0  0.074761  0.231278   0.231278
# 519  Manchester United    0  0.000000  0.000000   0.000000
# 520   Sheffield United    0  0.000000  0.000000   0.000000
# 521             Fulham    0  0.000000  0.000000   0.000000

# %% [markdown]
# ## Menelaah Data
# ---

# %%
# mengungkap tipe-tipe data dari setiap kolom
print(df.dtypes)
# Out:
# Unnamed: 0        int64
# id                int64
# player_name      object
# games             int64
# time              int64
# goals             int64
# xG              float64
# assists           int64
# xA              float64
# shots             int64
# key_passes        int64
# yellow_cards      int64
# red_cards         int64
# position         object
# team_title       object
# npg               int64
# npxG            float64
# xGChain         float64
# xGBuildup       float64
# dtype: object

# %% [markdown]
# Dari hasil output diatas terlihat bahwa 2 kolom pertama (yaitu: 'Unnamed: 0', dan 'id') hanyalah data numerik yang biasanya tidak memiliki makna rill, sehingga kita bisa tidak gunakan kolom/field tsb.

# %%
df_noid = df.iloc[:,2:]
df_noid
# Out:
#                 player_name  games  time  goals         xG  assists  \
# 0                Harry Kane     35  3097     23  22.174859       14
# 1             Mohamed Salah     37  3085     22  20.250847        5
# 2           Bruno Fernandes     37  3117     18  16.019454       12
# 3             Son Heung-Min     37  3139     17  11.023287       10
# 4           Patrick Bamford     38  3085     17  18.401863        7
# ..                      ...    ...   ...    ...        ...      ...
# 517  Jaden Philogene-Bidace      1     1      0   0.000000        0
# 518         Gaetano Berardi      2   113      0   0.074761        0
# 519          Anthony Elanga      1    67      0   0.000000        0
# 520             Femi Seriki      1     1      0   0.000000        0
# 521         Tyrese Francois      1    13      0   0.000000        0
#
#             xA  shots  key_passes  yellow_cards  red_cards position  \
# 0     7.577094    138          49             1          0        F
# 1     6.528526    126          55             0          0    F M S
# 2    11.474996    121          95             6          0      M S
# 3     9.512992     68          75             0          0    F M S
# 4     3.782247    107          30             3          0      F S
# ..         ...    ...         ...           ...        ...      ...
# 517   0.000000      0           0             0          0        S
# 518   0.000000      1           0             0          0      D S
# 519   0.000000      0           0             0          0        M
# 520   0.000000      0           0             0          0        S
# 521   0.000000      0           0             0          0        S
#
#             team_title  npg       npxG    xGChain  xGBuildup
# 0            Tottenham   19  19.130183  24.995648   4.451257
# 1            Liverpool   16  15.683834  28.968234   9.800236
# 2    Manchester United    9   8.407840  26.911412  11.932285
# 3            Tottenham   16  10.262118  20.671916   6.608751
# 4                Leeds   15  16.879525  23.394953   4.131796
# ..                 ...  ...        ...        ...        ...
# 517        Aston Villa    0   0.000000   0.056044   0.056044
# 518              Leeds    0   0.074761   0.231278   0.231278
# 519  Manchester United    0   0.000000   0.000000   0.000000
# 520   Sheffield United    0   0.000000   0.000000   0.000000
# 521             Fulham    0   0.000000   0.000000   0.000000
#
# [522 rows x 17 columns]

# %%
# menampilkan statistik dasar setiap kolom data yang bertipe numerik.
df_noid.describe()
# Out:
#             games         time       goals          xG     assists  \
# count  522.000000   522.000000  522.000000  522.000000  522.000000
# mean    19.643678  1420.068966    1.862069    2.000806    1.289272
# std     11.619836  1031.604819    3.338851    3.317946    2.083350
# min      1.000000     1.000000    0.000000    0.000000    0.000000
# 25%     10.000000   470.250000    0.000000    0.074668    0.000000
# 50%     21.000000  1342.000000    1.000000    0.737295    0.000000
# 75%     30.000000  2319.000000    2.000000    2.053378    2.000000
# max     38.000000  3420.000000   23.000000   22.174859   14.000000
#
#                xA       shots  key_passes  yellow_cards   red_cards  \
# count  522.000000  522.000000  522.000000    522.000000  522.000000
# mean     1.376029   17.379310   12.963602      2.061303    0.091954
# std      1.886510   21.572664   16.164361      2.203661    0.295800
# min      0.000000    0.000000    0.000000      0.000000    0.000000
# 25%      0.049245    2.000000    1.000000      0.000000    0.000000
# 50%      0.691122   10.000000    7.000000      2.000000    0.000000
# 75%      2.050509   23.750000   19.000000      3.000000    0.000000
# max     11.474996  138.000000   95.000000     12.000000    2.000000
#
#               npg        npxG     xGChain   xGBuildup
# count  522.000000  522.000000  522.000000  522.000000
# mean     1.668582    1.821450    5.663368    3.455060
# std      2.909929    2.931176    5.600249    3.376584
# min      0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    0.074668    1.191391    0.720353
# 50%      0.500000    0.715585    4.252738    2.656397
# 75%      2.000000    1.945799    8.308002    5.254647
# max     19.000000   19.130183   28.968234   18.323006

# %%
# jika ingin menampilkan juga statistik kolom- 
# yang bertipe non-numerik, mencakup beberapa banyak nilai unik- 
# dalam kolom (unique), nilai modus(top), serta frekuensi modus(freq)
df_noid.describe(include="all")
# Out:
#             player_name       games         time       goals          xG  \
# count               522  522.000000   522.000000  522.000000  522.000000
# unique              522         NaN          NaN         NaN         NaN
# top     Tyrese Francois         NaN          NaN         NaN         NaN
# freq                  1         NaN          NaN         NaN         NaN
# mean                NaN   19.643678  1420.068966    1.862069    2.000806
# std                 NaN   11.619836  1031.604819    3.338851    3.317946
# min                 NaN    1.000000     1.000000    0.000000    0.000000
# 25%                 NaN   10.000000   470.250000    0.000000    0.074668
# 50%                 NaN   21.000000  1342.000000    1.000000    0.737295
# 75%                 NaN   30.000000  2319.000000    2.000000    2.053378
# max                 NaN   38.000000  3420.000000   23.000000   22.174859
#
#            assists          xA       shots  key_passes  yellow_cards  \
# count   522.000000  522.000000  522.000000  522.000000    522.000000
# unique         NaN         NaN         NaN         NaN           NaN
# top            NaN         NaN         NaN         NaN           NaN
# freq           NaN         NaN         NaN         NaN           NaN
# mean      1.289272    1.376029   17.379310   12.963602      2.061303
# std       2.083350    1.886510   21.572664   16.164361      2.203661
# min       0.000000    0.000000    0.000000    0.000000      0.000000
# 25%       0.000000    0.049245    2.000000    1.000000      0.000000
# 50%       0.000000    0.691122   10.000000    7.000000      2.000000
# 75%       2.000000    2.050509   23.750000   19.000000      3.000000
# max      14.000000   11.474996  138.000000   95.000000     12.000000
#
#          red_cards position team_title         npg        npxG     xGChain  \
# count   522.000000      522        522  522.000000  522.000000  522.000000
# unique         NaN       14         28         NaN         NaN         NaN
# top            NaN      M S    Everton         NaN         NaN         NaN
# freq           NaN      106         28         NaN         NaN         NaN
# mean      0.091954      NaN        NaN    1.668582    1.821450    5.663368
# std       0.295800      NaN        NaN    2.909929    2.931176    5.600249
# min       0.000000      NaN        NaN    0.000000    0.000000    0.000000
# 25%       0.000000      NaN        NaN    0.000000    0.074668    1.191391
# 50%       0.000000      NaN        NaN    0.500000    0.715585    4.252738
# 75%       0.000000      NaN        NaN    2.000000    1.945799    8.308002
# max       2.000000      NaN        NaN   19.000000   19.130183   28.968234
#
#          xGBuildup
# count   522.000000
# unique         NaN
# top            NaN
# freq           NaN
# mean      3.455060
# std       3.376584
# min       0.000000
# 25%       0.720353
# 50%       2.656397
# 75%       5.254647
# max      18.323006

# %% [markdown]
# ### Contoh fungsi statistik setiap kolom (yang applicable)
# ---

# %%
df_noid.mean()

# %%
df_noid.sum()
# Out:
# player_name     Harry KaneMohamed SalahBruno FernandesSon Heun...
# games                                                       10254
# time                                                       741276
# goals                                                         972
# xG                                                    1044.420572
# assists                                                       673
# xA                                                     718.287269
# shots                                                        9072
# key_passes                                                   6767
# yellow_cards                                                 1076
# red_cards                                                      48
# position        FF M SM SF M SF SF SF SFM SF M SF SF SF SF SF ...
# team_title      TottenhamLiverpoolManchester UnitedTottenhamLe...
# npg                                                           871
# npxG                                                     950.7971
# xGChain                                               2956.278233
# xGBuildup                                             1803.541131
# dtype: object

# %%
df_noid.median()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 df_noid.median()
#
# File ~/miniconda3/envs/ml-week2/lib/python3.10/site-packages/pandas/core/frame.py:11733, in DataFrame.median(self, axis, skipna, numeric_only, **kwargs)
#   11725 @doc(make_doc("median", ndim=2))
#   11726 def median(
#   11727     self,
#    (...)
#   11731     **kwargs,
#   11732 ):
# > 11733     result = super().median(axis, skipna, numeric_only, **kwargs)
#   11734     if isinstance(result, Series):
#   11735         result = result.__finalize__(self, method="median")
#
# File ~/miniconda3/envs/ml-week2/lib/python3.10/site-packages/pandas/core/generic.py:12496, in NDFrame.median(self, axis, skipna, numeric_only, **kwargs)
#   12489 def median(
#   12490     self,
#   12491     axis: Axis | None = 0,
#    (...)
#   12494     **kwargs,
#   12495 ) -> Series | float:
# > 12496     return self._stat_function(
#   12497         "median", nanops.nanmedian, axis, skipna, numeric_only, **kwargs
#   12498     )
#
# File ~/miniconda3/envs/ml-week2/lib/python3.10/site-packages/pandas/core/generic.py:12442, in NDFrame._stat_function(self, name, func, axis, skipna, numeric_only, **kwargs)
#   12438 nv.validate_func(name, (), kwargs)
#   12440 validate_bool_kwarg(skipna, "skipna", none_allowed=False)
# > 12442 return self._reduce(
#   12443     func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   12444 )
#
# File ~/miniconda3/envs/ml-week2/lib/python3.10/site-packages/pandas/core/frame.py:11589, in DataFrame._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#   11585     df = df.T
#   11587 # After possibly _get_data and transposing, we are now in the
#   11588 #  simple case where we can use BlockManager.reduce
# > 11589 res = df._mgr.reduce(blk_func)
#   11590 out = df._constructor_from_mgr(res, axes=res.axes).iloc[0]
#   11591 if out_dtype is not None and out.dtype != "boolean":
#
# File ~/miniconda3/envs/ml-week2/lib/python3.10/site-packages/pandas/core/internals/managers.py:1519, in BlockManager.reduce(self, func)
#    1517 res_blocks: list[Block] = []
#    1518 for blk in self.blocks:
# -> 1519     nbs = blk.reduce(func)
#    1520     res_blocks.extend(nbs)
#    1522 index = Index([None])  # placeholder
#
# File ~/miniconda3/envs/ml-week2/lib/python3.10/site-packages/pandas/core/internals/blocks.py:406, in Block.reduce(self, func)
#     400 @final
#     401 def reduce(self, func) -> list[Block]:
#     402     # We will apply the function and reshape the result into a single-row
#     403     #  Block with the same mgr_locs; squeezing will be done at a higher level
#     404     assert self.ndim == 2
# --> 406     result = func(self.values)
#     408     if self.values.ndim == 1:
#     409         res_values = result
#
# File ~/miniconda3/envs/ml-week2/lib/python3.10/site-packages/pandas/core/frame.py:11508, in DataFrame._reduce.<locals>.blk_func(values, axis)
#   11506         return np.array([result])
#   11507 else:
# > 11508     return op(values, axis=axis, skipna=skipna, **kwds)
#
# File ~/miniconda3/envs/ml-week2/lib/python3.10/site-packages/pandas/core/nanops.py:147, in bottleneck_switch.__call__.<locals>.f(values, axis, skipna, **kwds)
#     145         result = alt(values, axis=axis, skipna=skipna, **kwds)
#     146 else:
# --> 147     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     149 return result
#
# File ~/miniconda3/envs/ml-week2/lib/python3.10/site-packages/pandas/core/nanops.py:787, in nanmedian(values, axis, skipna, mask)
#     785     inferred = lib.infer_dtype(values)
#     786     if inferred in ["string", "mixed"]:
# --> 787         raise TypeError(f"Cannot convert {values} to numeric")
#     788 try:
#     789     values = values.astype("f8")
#
# TypeError: Cannot convert [['Harry Kane' 'Mohamed Salah' 'Bruno Fernandes' ... 'Anthony Elanga'
#   'Femi Seriki' 'Tyrese Francois']
#  ['F' 'F M S' 'M S' ... 'M' 'S' 'S']
#  ['Tottenham' 'Liverpool' 'Manchester United' ... 'Manchester United'
#   'Sheffield United' 'Fulham']] to numeric

# %%
df_noid.var()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/miniconda3/envs/ml-week2/lib/python3.10/site-packages/pandas/core/nanops.py:85, in disallow.__call__.<locals>._f(*args, **kwargs)
#      84 try:
# ---> 85     return f(*args, **kwargs)
#      86 except ValueError as e:
#      87     # we want to transform an object array
#      88     # ValueError message to the more typical TypeError
#      89     # e.g. this is normally a disallowed function on
#      90     # object arrays that contain strings
#
# File ~/miniconda3/envs/ml-week2/lib/python3.10/site-packages/pandas/core/nanops.py:147, in bottleneck_switch.__call__.<locals>.f(values, axis, skipna, **kwds)
#     146 else:
# --> 147     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     149 return result
#
# File ~/miniconda3/envs/ml-week2/lib/python3.10/site-packages/pandas/core/nanops.py:1013, in nanvar(values, axis, skipna, ddof, mask)
#    1007 # xref GH10242
#    1008 # Compute variance via two-pass algorithm, which is stable against
#    1009 # cancellation errors and relatively accurate for small numbers of
#    1010 # observations.
#    1011 #
#    1012 # See https://en.wikipedia.org/wiki/Algorithms_for_calculating_variance
# -> 1013 avg = _ensure_numeric(values.sum(axis=axis, dtype=np.float64)) / count
#    1014 if axis is not None:
#
# File ~/miniconda3/envs/ml-week2/lib/python3.10/site-packages/numpy/_core/_methods.py:52, in _sum(a, axis, dtype, out, keepdims, initial, where)
#      50 def _sum(a, axis=None, dtype=None, out=None, keepdims=False,
#      51          initial=_NoValue, where=True):
# ---> 52     return umr_sum(a, axis, dtype, out, keepdims, initial, where)
#
# ValueError: could not convert string to float: 'Harry Kane'
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 df_noid.var()
#
# File ~/miniconda3/envs/ml-week2/lib/python3.10/site-packages/pandas/core/frame.py:11761, in DataFrame.var(self, axis, skipna, ddof, numeric_only, **kwargs)
#   11752 @doc(make_doc("var", ndim=2))
#   11753 def var(
#   11754     self,
#    (...)
#   11759     **kwargs,
#   11760 ):
# > 11761     result = super().var(axis, skipna, ddof, numeric_only, **kwargs)
#   11762     if isinstance(result, Series):
#   11763         result = result.__finalize__(self, method="var")
#
# File ~/miniconda3/envs/ml-week2/lib/python3.10/site-packages/pandas/core/generic.py:12411, in NDFrame.var(self, axis, skipna, ddof, numeric_only, **kwargs)
#   12403 def var(
#   12404     self,
#   12405     axis: Axis | None = 0,
#    (...)
#   12409     **kwargs,
#   12410 ) -> Series | float:
# > 12411     return self._stat_function_ddof(
#   12412         "var", nanops.nanvar, axis, skipna, ddof, numeric_only, **kwargs
#   12413     )
#
# File ~/miniconda3/envs/ml-week2/lib/python3.10/site-packages/pandas/core/generic.py:12387, in NDFrame._stat_function_ddof(self, name, func, axis, skipna, ddof, numeric_only, **kwargs)
#   12384 elif axis is lib.no_default:
#   12385     axis = 0
# > 12387 return self._reduce(
#   12388     func, name, axis=axis, numeric_only=numeric_only, skipna=skipna, ddof=ddof
#   12389 )
#
# File ~/miniconda3/envs/ml-week2/lib/python3.10/site-packages/pandas/core/frame.py:11589, in DataFrame._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#   11585     df = df.T
#   11587 # After possibly _get_data and transposing, we are now in the
#   11588 #  simple case where we can use BlockManager.reduce
# > 11589 res = df._mgr.reduce(blk_func)
#   11590 out = df._constructor_from_mgr(res, axes=res.axes).iloc[0]
#   11591 if out_dtype is not None and out.dtype != "boolean":
#
# File ~/miniconda3/envs/ml-week2/lib/python3.10/site-packages/pandas/core/internals/managers.py:1519, in BlockManager.reduce(self, func)
#    1517 res_blocks: list[Block] = []
#    1518 for blk in self.blocks:
# -> 1519     nbs = blk.reduce(func)
#    1520     res_blocks.extend(nbs)
#    1522 index = Index([None])  # placeholder
#
# File ~/miniconda3/envs/ml-week2/lib/python3.10/site-packages/pandas/core/internals/blocks.py:406, in Block.reduce(self, func)
#     400 @final
#     401 def reduce(self, func) -> list[Block]:
#     402     # We will apply the function and reshape the result into a single-row
#     403     #  Block with the same mgr_locs; squeezing will be done at a higher level
#     404     assert self.ndim == 2
# --> 406     result = func(self.values)
#     408     if self.values.ndim == 1:
#     409         res_values = result
#
# File ~/miniconda3/envs/ml-week2/lib/python3.10/site-packages/pandas/core/frame.py:11508, in DataFrame._reduce.<locals>.blk_func(values, axis)
#   11506         return np.array([result])
#   11507 else:
# > 11508     return op(values, axis=axis, skipna=skipna, **kwds)
#
# File ~/miniconda3/envs/ml-week2/lib/python3.10/site-packages/pandas/core/nanops.py:92, in disallow.__call__.<locals>._f(*args, **kwargs)
#      86 except ValueError as e:
#      87     # we want to transform an object array
#      88     # ValueError message to the more typical TypeError
#      89     # e.g. this is normally a disallowed function on
#      90     # object arrays that contain strings
#      91     if is_object_dtype(args[0]):
# ---> 92         raise TypeError(e) from e
#      93     raise
#
# TypeError: could not convert string to float: 'Harry Kane'

# %%
df_noid.std()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/miniconda3/envs/ml-week2/lib/python3.10/site-packages/pandas/core/nanops.py:85, in disallow.__call__.<locals>._f(*args, **kwargs)
#      84 try:
# ---> 85     return f(*args, **kwargs)
#      86 except ValueError as e:
#      87     # we want to transform an object array
#      88     # ValueError message to the more typical TypeError
#      89     # e.g. this is normally a disallowed function on
#      90     # object arrays that contain strings
#
# File ~/miniconda3/envs/ml-week2/lib/python3.10/site-packages/pandas/core/nanops.py:147, in bottleneck_switch.__call__.<locals>.f(values, axis, skipna, **kwds)
#     146 else:
# --> 147     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     149 return result
#
# File ~/miniconda3/envs/ml-week2/lib/python3.10/site-packages/pandas/core/nanops.py:1013, in nanvar(values, axis, skipna, ddof, mask)
#    1007 # xref GH10242
#    1008 # Compute variance via two-pass algorithm, which is stable against
#    1009 # cancellation errors and relatively accurate for small numbers of
#    1010 # observations.
#    1011 #
#    1012 # See https://en.wikipedia.org/wiki/Algorithms_for_calculating_variance
# -> 1013 avg = _ensure_numeric(values.sum(axis=axis, dtype=np.float64)) / count
#    1014 if axis is not None:
#
# File ~/miniconda3/envs/ml-week2/lib/python3.10/site-packages/numpy/_core/_methods.py:52, in _sum(a, axis, dtype, out, keepdims, initial, where)
#      50 def _sum(a, axis=None, dtype=None, out=None, keepdims=False,
#      51          initial=_NoValue, where=True):
# ---> 52     return umr_sum(a, axis, dtype, out, keepdims, initial, where)
#
# ValueError: could not convert string to float: 'Harry Kane'
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 df_noid.std()
#
# File ~/miniconda3/envs/ml-week2/lib/python3.10/site-packages/pandas/core/frame.py:11775, in DataFrame.std(self, axis, skipna, ddof, numeric_only, **kwargs)
#   11766 @doc(make_doc("std", ndim=2))
#   11767 def std(
#   11768     self,
#    (...)
#   11773     **kwargs,
#   11774 ):
# > 11775     result = super().std(axis, skipna, ddof, numeric_only, **kwargs)
#   11776     if isinstance(result, Series):
#   11777         result = result.__finalize__(self, method="std")
#
# File ~/miniconda3/envs/ml-week2/lib/python3.10/site-packages/pandas/core/generic.py:12423, in NDFrame.std(self, axis, skipna, ddof, numeric_only, **kwargs)
#   12415 def std(
#   12416     self,
#   12417     axis: Axis | None = 0,
#    (...)
#   12421     **kwargs,
#   12422 ) -> Series | float:
# > 12423     return self._stat_function_ddof(
#   12424         "std", nanops.nanstd, axis, skipna, ddof, numeric_only, **kwargs
#   12425     )
#
# File ~/miniconda3/envs/ml-week2/lib/python3.10/site-packages/pandas/core/generic.py:12387, in NDFrame._stat_function_ddof(self, name, func, axis, skipna, ddof, numeric_only, **kwargs)
#   12384 elif axis is lib.no_default:
#   12385     axis = 0
# > 12387 return self._reduce(
#   12388     func, name, axis=axis, numeric_only=numeric_only, skipna=skipna, ddof=ddof
#   12389 )
#
# File ~/miniconda3/envs/ml-week2/lib/python3.10/site-packages/pandas/core/frame.py:11589, in DataFrame._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#   11585     df = df.T
#   11587 # After possibly _get_data and transposing, we are now in the
#   11588 #  simple case where we can use BlockManager.reduce
# > 11589 res = df._mgr.reduce(blk_func)
#   11590 out = df._constructor_from_mgr(res, axes=res.axes).iloc[0]
#   11591 if out_dtype is not None and out.dtype != "boolean":
#
# File ~/miniconda3/envs/ml-week2/lib/python3.10/site-packages/pandas/core/internals/managers.py:1519, in BlockManager.reduce(self, func)
#    1517 res_blocks: list[Block] = []
#    1518 for blk in self.blocks:
# -> 1519     nbs = blk.reduce(func)
#    1520     res_blocks.extend(nbs)
#    1522 index = Index([None])  # placeholder
#
# File ~/miniconda3/envs/ml-week2/lib/python3.10/site-packages/pandas/core/internals/blocks.py:406, in Block.reduce(self, func)
#     400 @final
#     401 def reduce(self, func) -> list[Block]:
#     402     # We will apply the function and reshape the result into a single-row
#     403     #  Block with the same mgr_locs; squeezing will be done at a higher level
#     404     assert self.ndim == 2
# --> 406     result = func(self.values)
#     408     if self.values.ndim == 1:
#     409         res_values = result
#
# File ~/miniconda3/envs/ml-week2/lib/python3.10/site-packages/pandas/core/frame.py:11508, in DataFrame._reduce.<locals>.blk_func(values, axis)
#   11506         return np.array([result])
#   11507 else:
# > 11508     return op(values, axis=axis, skipna=skipna, **kwds)
#
# File ~/miniconda3/envs/ml-week2/lib/python3.10/site-packages/pandas/core/nanops.py:147, in bottleneck_switch.__call__.<locals>.f(values, axis, skipna, **kwds)
#     145         result = alt(values, axis=axis, skipna=skipna, **kwds)
#     146 else:
# --> 147     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     149 return result
#
# File ~/miniconda3/envs/ml-week2/lib/python3.10/site-packages/pandas/core/nanops.py:950, in nanstd(values, axis, skipna, ddof, mask)
#     947 orig_dtype = values.dtype
#     948 values, mask = _get_values(values, skipna, mask=mask)
# --> 950 result = np.sqrt(nanvar(values, axis=axis, skipna=skipna, ddof=ddof, mask=mask))
#     951 return _wrap_results(result, orig_dtype)
#
# File ~/miniconda3/envs/ml-week2/lib/python3.10/site-packages/pandas/core/nanops.py:92, in disallow.__call__.<locals>._f(*args, **kwargs)
#      86 except ValueError as e:
#      87     # we want to transform an object array
#      88     # ValueError message to the more typical TypeError
#      89     # e.g. this is normally a disallowed function on
#      90     # object arrays that contain strings
#      91     if is_object_dtype(args[0]):
# ---> 92         raise TypeError(e) from e
#      93     raise
#
# TypeError: could not convert string to float: 'Harry Kane'

# %%
df_noid.quantile(0.75)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 df_noid.quantile(0.75)
#
# File ~/miniconda3/envs/ml-week2/lib/python3.10/site-packages/pandas/core/frame.py:12173, in DataFrame.quantile(self, q, axis, numeric_only, interpolation, method)
#   12167 axis = self._get_axis_number(axis)
#   12169 if not is_list_like(q):
#   12170     # BlockManager.quantile expects listlike, so we wrap and unwrap here
#   12171     # error: List item 0 has incompatible type "float | ExtensionArray |
#   12172     # ndarray[Any, Any] | Index | Series | Sequence[float]"; expected "float"
# > 12173     res_df = self.quantile(
#   12174         [q],  # type: ignore[list-item]
#   12175         axis=axis,
#   12176         numeric_only=numeric_only,
#   12177         interpolation=interpolation,
#   12178         method=method,
#   12179     )
#   12180     if method == "single":
#   12181         res = res_df.iloc[0]
#
# File ~/miniconda3/envs/ml-week2/lib/python3.10/site-packages/pandas/core/frame.py:12218, in DataFrame.quantile(self, q, axis, numeric_only, interpolation, method)
#   12214     raise ValueError(
#   12215         f"Invalid method: {method}. Method must be in {valid_method}."
#   12216     )
#   12217 if method == "single":
# > 12218     res = data._mgr.quantile(qs=q, interpolation=interpolation)
#   12219 elif method == "table":
#   12220     valid_interpolation = {"nearest", "lower", "higher"}
#
# File ~/miniconda3/envs/ml-week2/lib/python3.10/site-packages/pandas/core/internals/managers.py:1567, in BlockManager.quantile(self, qs, interpolation)
#    1564 new_axes = list(self.axes)
#    1565 new_axes[1] = Index(qs, dtype=np.float64)
# -> 1567 blocks = [
#    1568     blk.quantile(qs=qs, interpolation=interpolation) for blk in self.blocks
#    1569 ]
#    1571 return type(self)(blocks, new_axes)
#
# File ~/miniconda3/envs/ml-week2/lib/python3.10/site-packages/pandas/core/internals/managers.py:1568, in <listcomp>(.0)
#    1564 new_axes = list(self.axes)
#    1565 new_axes[1] = Index(qs, dtype=np.float64)
#    1567 blocks = [
# -> 1568     blk.quantile(qs=qs, interpolation=interpolation) for blk in self.blocks
#    1569 ]
#    1571 return type(self)(blocks, new_axes)
#
# File ~/miniconda3/envs/ml-week2/lib/python3.10/site-packages/pandas/core/internals/blocks.py:1957, in Block.quantile(self, qs, interpolation)
#    1954 assert self.ndim == 2
#    1955 assert is_list_like(qs)  # caller is responsible for this
# -> 1957 result = quantile_compat(self.values, np.asarray(qs._values), interpolation)
#    1958 # ensure_block_shape needed for cases where we start with EA and result
#    1959 #  is ndarray, e.g. IntegerArray, SparseArray
#    1960 result = ensure_block_shape(result, ndim=2)
#
# File ~/miniconda3/envs/ml-week2/lib/python3.10/site-packages/pandas/core/array_algos/quantile.py:39, in quantile_compat(values, qs, interpolation)
#      37     fill_value = na_value_for_dtype(values.dtype, compat=False)
#      38     mask = isna(values)
# ---> 39     return quantile_with_mask(values, mask, fill_value, qs, interpolation)
#      40 else:
#      41     return values._quantile(qs, interpolation)
#
# File ~/miniconda3/envs/ml-week2/lib/python3.10/site-packages/pandas/core/array_algos/quantile.py:97, in quantile_with_mask(values, mask, fill_value, qs, interpolation)
#      95     result = np.repeat(flat, len(values)).reshape(len(values), len(qs))
#      96 else:
# ---> 97     result = _nanpercentile(
#      98         values,
#      99         qs * 100.0,
#     100         na_value=fill_value,
#     101         mask=mask,
#     102         interpolation=interpolation,
#     103     )
#     105     result = np.asarray(result)
#     106     result = result.T
#
# File ~/miniconda3/envs/ml-week2/lib/python3.10/site-packages/pandas/core/array_algos/quantile.py:218, in _nanpercentile(values, qs, na_value, mask, interpolation)
#     216     return result
#     217 else:
# --> 218     return np.percentile(
#     219         values,
#     220         qs,
#     221         axis=1,
#     222         # error: No overload variant of "percentile" matches argument types
#     223         # "ndarray[Any, Any]", "ndarray[Any, dtype[floating[_64Bit]]]",
#     224         # "int", "Dict[str, str]"  [call-overload]
#     225         method=interpolation,  # type: ignore[call-overload]
#     226     )
#
# File ~/miniconda3/envs/ml-week2/lib/python3.10/site-packages/numpy/lib/_function_base_impl.py:4273, in percentile(a, q, axis, out, overwrite_input, method, keepdims, weights, interpolation)
#    4270     if np.any(weights < 0):
#    4271         raise ValueError("Weights must be non-negative.")
# -> 4273 return _quantile_unchecked(
#    4274     a, q, axis, out, overwrite_input, method, keepdims, weights)
#
# File ~/miniconda3/envs/ml-week2/lib/python3.10/site-packages/numpy/lib/_function_base_impl.py:4550, in _quantile_unchecked(a, q, axis, out, overwrite_input, method, keepdims, weights)
#    4541 def _quantile_unchecked(a,
#    4542                         q,
#    4543                         axis=None,
#    (...)
#    4547                         keepdims=False,
#    4548                         weights=None):
#    4549     """Assumes that q is in [0, 1], and is an ndarray"""
# -> 4550     return _ureduce(a,
#    4551                     func=_quantile_ureduce_func,
#    4552                     q=q,
#    4553                     weights=weights,
#    4554                     keepdims=keepdims,
#    4555                     axis=axis,
#    4556                     out=out,
#    4557                     overwrite_input=overwrite_input,
#    4558                     method=method)
#
# File ~/miniconda3/envs/ml-week2/lib/python3.10/site-packages/numpy/lib/_function_base_impl.py:3894, in _ureduce(a, func, keepdims, **kwargs)
#    3891             index_out = (0, ) * nd
#    3892             kwargs['out'] = out[(Ellipsis, ) + index_out]
# -> 3894 r = func(a, **kwargs)
#    3896 if out is not None:
#    3897     return out
#
# File ~/miniconda3/envs/ml-week2/lib/python3.10/site-packages/numpy/lib/_function_base_impl.py:4727, in _quantile_ureduce_func(a, q, weights, axis, out, overwrite_input, method)
#    4725         arr = a.copy()
#    4726         wgt = weights
# -> 4727 result = _quantile(arr,
#    4728                    quantiles=q,
#    4729                    axis=axis,
#    4730                    method=method,
#    4731                    out=out,
#    4732                    weights=wgt)
#    4733 return result
#
# File ~/miniconda3/envs/ml-week2/lib/python3.10/site-packages/numpy/lib/_function_base_impl.py:4859, in _quantile(arr, quantiles, axis, method, out, weights)
#    4857         result_shape = virtual_indexes.shape + (1,) * (arr.ndim - 1)
#    4858         gamma = gamma.reshape(result_shape)
# -> 4859         result = _lerp(previous,
#    4860                     next,
#    4861                     gamma,
#    4862                     out=out)
#    4863 else:
#    4864     # Weighted case
#    4865     # This implements method="inverted_cdf", the only supported weighted
#    4866     # method, which needs to sort anyway.
#    4867     weights = np.asanyarray(weights)
#
# File ~/miniconda3/envs/ml-week2/lib/python3.10/site-packages/numpy/lib/_function_base_impl.py:4653, in _lerp(a, b, t, out)
#    4639 def _lerp(a, b, t, out=None):
#    4640     """
#    4641     Compute the linear interpolation weighted by gamma on each point of
#    4642     two same shape array.
#    (...)
#    4651         Output array.
#    4652     """
# -> 4653     diff_b_a = subtract(b, a)
#    4654     # asanyarray is a stop-gap until gh-13105
#    4655     lerp_interpolation = asanyarray(add(a, diff_b_a * t, out=out))
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'

# %% [markdown]
# ### Mencari pencilan dengan Tukey's fences (1)
# ---

# %%
q1 = df_noid.quantile(0.25)
q3 = df_noid.quantile(0.75)
iqr = q3 - q1
iqr
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 q1 = df_noid.quantile(0.25)
#       2 q3 = df_noid.quantile(0.75)
#       3 iqr = q3 - q1
#
# File ~/miniconda3/envs/ml-week2/lib/python3.10/site-packages/pandas/core/frame.py:12173, in DataFrame.quantile(self, q, axis, numeric_only, interpolation, method)
#   12167 axis = self._get_axis_number(axis)
#   12169 if not is_list_like(q):
#   12170     # BlockManager.quantile expects listlike, so we wrap and unwrap here
#   12171     # error: List item 0 has incompatible type "float | ExtensionArray |
#   12172     # ndarray[Any, Any] | Index | Series | Sequence[float]"; expected "float"
# > 12173     res_df = self.quantile(
#   12174         [q],  # type: ignore[list-item]
#   12175         axis=axis,
#   12176         numeric_only=numeric_only,
#   12177         interpolation=interpolation,
#   12178         method=method,
#   12179     )
#   12180     if method == "single":
#   12181         res = res_df.iloc[0]
#
# File ~/miniconda3/envs/ml-week2/lib/python3.10/site-packages/pandas/core/frame.py:12218, in DataFrame.quantile(self, q, axis, numeric_only, interpolation, method)
#   12214     raise ValueError(
#   12215         f"Invalid method: {method}. Method must be in {valid_method}."
#   12216     )
#   12217 if method == "single":
# > 12218     res = data._mgr.quantile(qs=q, interpolation=interpolation)
#   12219 elif method == "table":
#   12220     valid_interpolation = {"nearest", "lower", "higher"}
#
# File ~/miniconda3/envs/ml-week2/lib/python3.10/site-packages/pandas/core/internals/managers.py:1567, in BlockManager.quantile(self, qs, interpolation)
#    1564 new_axes = list(self.axes)
#    1565 new_axes[1] = Index(qs, dtype=np.float64)
# -> 1567 blocks = [
#    1568     blk.quantile(qs=qs, interpolation=interpolation) for blk in self.blocks
#    1569 ]
#    1571 return type(self)(blocks, new_axes)
#
# File ~/miniconda3/envs/ml-week2/lib/python3.10/site-packages/pandas/core/internals/managers.py:1568, in <listcomp>(.0)
#    1564 new_axes = list(self.axes)
#    1565 new_axes[1] = Index(qs, dtype=np.float64)
#    1567 blocks = [
# -> 1568     blk.quantile(qs=qs, interpolation=interpolation) for blk in self.blocks
#    1569 ]
#    1571 return type(self)(blocks, new_axes)
#
# File ~/miniconda3/envs/ml-week2/lib/python3.10/site-packages/pandas/core/internals/blocks.py:1957, in Block.quantile(self, qs, interpolation)
#    1954 assert self.ndim == 2
#    1955 assert is_list_like(qs)  # caller is responsible for this
# -> 1957 result = quantile_compat(self.values, np.asarray(qs._values), interpolation)
#    1958 # ensure_block_shape needed for cases where we start with EA and result
#    1959 #  is ndarray, e.g. IntegerArray, SparseArray
#    1960 result = ensure_block_shape(result, ndim=2)
#
# File ~/miniconda3/envs/ml-week2/lib/python3.10/site-packages/pandas/core/array_algos/quantile.py:39, in quantile_compat(values, qs, interpolation)
#      37     fill_value = na_value_for_dtype(values.dtype, compat=False)
#      38     mask = isna(values)
# ---> 39     return quantile_with_mask(values, mask, fill_value, qs, interpolation)
#      40 else:
#      41     return values._quantile(qs, interpolation)
#
# File ~/miniconda3/envs/ml-week2/lib/python3.10/site-packages/pandas/core/array_algos/quantile.py:97, in quantile_with_mask(values, mask, fill_value, qs, interpolation)
#      95     result = np.repeat(flat, len(values)).reshape(len(values), len(qs))
#      96 else:
# ---> 97     result = _nanpercentile(
#      98         values,
#      99         qs * 100.0,
#     100         na_value=fill_value,
#     101         mask=mask,
#     102         interpolation=interpolation,
#     103     )
#     105     result = np.asarray(result)
#     106     result = result.T
#
# File ~/miniconda3/envs/ml-week2/lib/python3.10/site-packages/pandas/core/array_algos/quantile.py:218, in _nanpercentile(values, qs, na_value, mask, interpolation)
#     216     return result
#     217 else:
# --> 218     return np.percentile(
#     219         values,
#     220         qs,
#     221         axis=1,
#     222         # error: No overload variant of "percentile" matches argument types
#     223         # "ndarray[Any, Any]", "ndarray[Any, dtype[floating[_64Bit]]]",
#     224         # "int", "Dict[str, str]"  [call-overload]
#     225         method=interpolation,  # type: ignore[call-overload]
#     226     )
#
# File ~/miniconda3/envs/ml-week2/lib/python3.10/site-packages/numpy/lib/_function_base_impl.py:4273, in percentile(a, q, axis, out, overwrite_input, method, keepdims, weights, interpolation)
#    4270     if np.any(weights < 0):
#    4271         raise ValueError("Weights must be non-negative.")
# -> 4273 return _quantile_unchecked(
#    4274     a, q, axis, out, overwrite_input, method, keepdims, weights)
#
# File ~/miniconda3/envs/ml-week2/lib/python3.10/site-packages/numpy/lib/_function_base_impl.py:4550, in _quantile_unchecked(a, q, axis, out, overwrite_input, method, keepdims, weights)
#    4541 def _quantile_unchecked(a,
#    4542                         q,
#    4543                         axis=None,
#    (...)
#    4547                         keepdims=False,
#    4548                         weights=None):
#    4549     """Assumes that q is in [0, 1], and is an ndarray"""
# -> 4550     return _ureduce(a,
#    4551                     func=_quantile_ureduce_func,
#    4552                     q=q,
#    4553                     weights=weights,
#    4554                     keepdims=keepdims,
#    4555                     axis=axis,
#    4556                     out=out,
#    4557                     overwrite_input=overwrite_input,
#    4558                     method=method)
#
# File ~/miniconda3/envs/ml-week2/lib/python3.10/site-packages/numpy/lib/_function_base_impl.py:3894, in _ureduce(a, func, keepdims, **kwargs)
#    3891             index_out = (0, ) * nd
#    3892             kwargs['out'] = out[(Ellipsis, ) + index_out]
# -> 3894 r = func(a, **kwargs)
#    3896 if out is not None:
#    3897     return out
#
# File ~/miniconda3/envs/ml-week2/lib/python3.10/site-packages/numpy/lib/_function_base_impl.py:4727, in _quantile_ureduce_func(a, q, weights, axis, out, overwrite_input, method)
#    4725         arr = a.copy()
#    4726         wgt = weights
# -> 4727 result = _quantile(arr,
#    4728                    quantiles=q,
#    4729                    axis=axis,
#    4730                    method=method,
#    4731                    out=out,
#    4732                    weights=wgt)
#    4733 return result
#
# File ~/miniconda3/envs/ml-week2/lib/python3.10/site-packages/numpy/lib/_function_base_impl.py:4859, in _quantile(arr, quantiles, axis, method, out, weights)
#    4857         result_shape = virtual_indexes.shape + (1,) * (arr.ndim - 1)
#    4858         gamma = gamma.reshape(result_shape)
# -> 4859         result = _lerp(previous,
#    4860                     next,
#    4861                     gamma,
#    4862                     out=out)
#    4863 else:
#    4864     # Weighted case
#    4865     # This implements method="inverted_cdf", the only supported weighted
#    4866     # method, which needs to sort anyway.
#    4867     weights = np.asanyarray(weights)
#
# File ~/miniconda3/envs/ml-week2/lib/python3.10/site-packages/numpy/lib/_function_base_impl.py:4653, in _lerp(a, b, t, out)
#    4639 def _lerp(a, b, t, out=None):
#    4640     """
#    4641     Compute the linear interpolation weighted by gamma on each point of
#    4642     two same shape array.
#    (...)
#    4651         Output array.
#    4652     """
# -> 4653     diff_b_a = subtract(b, a)
#    4654     # asanyarray is a stop-gap until gh-13105
#    4655     lerp_interpolation = asanyarray(add(a, diff_b_a * t, out=out))
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'

# %% [markdown]
# ### Mencari pencilan dengan Tukey's fences (2)
# ---

# %%
# handle warning 
import warnings 
warnings.filterwarnings('ignore')

# outlier filter
df_noid_align, iqr_new = df_noid.align(iqr, axis=1, copy=False, join='outer')
outlier_filter = (df_noid < q1 - 1.5 * iqr_new) | (df_noid > q3 + 1.5 * iqr_new)
outlier_filter
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 6
#       3 warnings.filterwarnings('ignore')
#       5 # outlier filter
# ----> 6 df_noid_align, iqr_new = df_noid.align(iqr, axis=1, copy=False, join='outer')
#       7 outlier_filter = (df_noid < q1 - 1.5 * iqr_new) | (df_noid > q3 + 1.5 * iqr_new)
#       8 outlier_filter
#
# NameError: name 'iqr' is not defined

# %% [markdown]
# ### Mencari pencilan dengan Tukey's fences (3)
# ---

# %%
df_noid[outlier_filter['assists']] \
    .loc[:, ['player_name', 'assists']] \
    .sort_values(by=['assists'], ascending=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 df_noid[outlier_filter['assists']] \
#       2     .loc[:, ['player_name', 'assists']] \
#       3     .sort_values(by=['assists'], ascending=False)
#
# NameError: name 'outlier_filter' is not defined

# %% [markdown]
# ### Value_counts()
# ---
# menghasilkan frekuensi setiap nilai unik di dalam kolom, yang tertinggi count-nya merupakan modus pada kolom tsb. Ada data dengan dua/tiga nama tim karena ada pemain yang bermain di dua/tiga klub dalam musim yang sama(ada transfer pemain)

# %%
df_noid['team_title'].value_counts()
# Out:
# team_title
# Everton                          28
# West Bromwich Albion             28
# Leicester                        27
# Liverpool                        27
# Southampton                      27
# Sheffield United                 27
# Wolverhampton Wanderers          27
# Manchester United                27
# Fulham                           27
# Arsenal                          26
# Newcastle United                 26
# Brighton                         26
# Burnley                          25
# Chelsea                          25
# Tottenham                        24
# Manchester City                  24
# Crystal Palace                   24
# Leeds                            23
# Aston Villa                      23
# West Ham                         23
# Arsenal,Newcastle United          1
# Everton,Southampton               1
# Aston Villa,Chelsea               1
# Liverpool,Southampton             1
# Chelsea,Fulham                    1
# West Bromwich Albion,West Ham     1
# Arsenal,West Bromwich Albion      1
# Arsenal,Brighton                  1
# Name: count, dtype: int64

# %% [markdown]
# ### Analisis dengan groupby
# ---
# method groupby memungkinkan analisa dilakukan secara per kelompok nilai atribut tertentu.
# misal: rerata dan simpangan baku gol per tim

# %%
df.groupby('team_title')['goals'].std()
# Out:
# team_title
# Arsenal                          3.352381
# Arsenal,Brighton                      NaN
# Arsenal,Newcastle United              NaN
# Arsenal,West Bromwich Albion          NaN
# Aston Villa                      3.696489
# Aston Villa,Chelsea                   NaN
# Brighton                         2.158703
# Burnley                          2.475210
# Chelsea                          2.350177
# Chelsea,Fulham                        NaN
# Crystal Palace                   2.901461
# Everton                          3.467727
# Everton,Southampton                   NaN
# Fulham                           1.439175
# Leeds                            4.153193
# Leicester                        4.020602
# Liverpool                        4.931439
# Liverpool,Southampton                 NaN
# Manchester City                  3.867132
# Manchester United                4.317855
# Newcastle United                 2.483174
# Sheffield United                 1.467599
# Southampton                      3.141941
# Tottenham                        5.855135
# West Bromwich Albion             2.310260
# West Bromwich Albion,West Ham         NaN
# West Ham                         3.369240
# Wolverhampton Wanderers          1.648620
# Name: goals, dtype: float64

# %%
df.groupby('team_title')['goals'].mean()
# Out:
# team_title
# Arsenal                          1.961538
# Arsenal,Brighton                 0.000000
# Arsenal,Newcastle United         8.000000
# Arsenal,West Bromwich Albion     0.000000
# Aston Villa                      2.130435
# Aston Villa,Chelsea              3.000000
# Brighton                         1.500000
# Burnley                          1.280000
# Chelsea                          2.240000
# Chelsea,Fulham                   1.000000
# Crystal Palace                   1.625000
# Everton                          1.607143
# Everton,Southampton              3.000000
# Fulham                           0.925926
# Leeds                            2.608696
# Leicester                        2.370370
# Liverpool                        2.370370
# Liverpool,Southampton            3.000000
# Manchester City                  3.208333
# Manchester United                2.518519
# Newcastle United                 1.384615
# Sheffield United                 0.666667
# Southampton                      1.555556
# Tottenham                        2.750000
# West Bromwich Albion             1.178571
# West Bromwich Albion,West Ham    0.000000
# West Ham                         2.478261
# Wolverhampton Wanderers          1.222222
# Name: goals, dtype: float64

# %% [markdown]
# ### Korelasi Pearson antara kolom-kolom numerik
# ---
# * Method corr() menghasilkan tabel korelasi pearson antar kolom-kolom numerik.
# * Rentang nilai: antara -1 dan 1
# * -1 = korelasi negatif | 0 = tidak ada korelasi linier | +1 = korelasi positif

# %%
df_noid.loc[:,'games':].corr()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 df_noid.loc[:,'games':].corr()
#
# File ~/miniconda3/envs/ml-week2/lib/python3.10/site-packages/pandas/core/frame.py:11076, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11074 cols = data.columns
#   11075 idx = cols.copy()
# > 11076 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11078 if method == "pearson":
#   11079     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~/miniconda3/envs/ml-week2/lib/python3.10/site-packages/pandas/core/frame.py:2002, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    2000 if dtype is not None:
#    2001     dtype = np.dtype(dtype)
# -> 2002 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    2003 if result.dtype is not dtype:
#    2004     result = np.asarray(result, dtype=dtype)
#
# File ~/miniconda3/envs/ml-week2/lib/python3.10/site-packages/pandas/core/internals/managers.py:1713, in BlockManager.as_array(self, dtype, copy, na_value)
#    1711         arr.flags.writeable = False
#    1712 else:
# -> 1713     arr = self._interleave(dtype=dtype, na_value=na_value)
#    1714     # The underlying data was copied within _interleave, so no need
#    1715     # to further copy if copy=True or setting na_value
#    1717 if na_value is lib.no_default:
#
# File ~/miniconda3/envs/ml-week2/lib/python3.10/site-packages/pandas/core/internals/managers.py:1772, in BlockManager._interleave(self, dtype, na_value)
#    1770     else:
#    1771         arr = blk.get_values(dtype)
# -> 1772     result[rl.indexer] = arr
#    1773     itemmask[rl.indexer] = 1
#    1775 if not itemmask.all():
#
# ValueError: could not convert string to float: 'F'
